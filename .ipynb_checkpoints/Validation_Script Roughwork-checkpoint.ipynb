# %%
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account
from datetime import timedelta, date

# %%
credentials = service_account.Credentials.from_service_account_file('watchdog_private_key.json', scopes=["https://www.googleapis.com/auth/cloud-platform"])

view_name = 'ga_jp_product_daily_kpi'
primary_diamention = 'Product_Name'
diamention_item = 'LR トートバッグ'
csv_file = 'Japan Product Name.csv'

project_id = 'watchdog-340107'
dataset_id = 'levis_jp_watchdog'
view_id = f'{project_id}.{dataset_id}.{view_name}'

date_col = 'Date'
start_date = date(2022,6,20) 
end_date = date(2022,7,20)
date_range = pd.date_range(start_date,end_date-timedelta(days=1),freq='d')


query_string_dim = f"""
        SELECT
        *
        FROM `{project_id}.{dataset_id}.{view_name}` 
        WHERE ({date_col} BETWEEN '{start_date}' AND '{end_date}') AND {primary_diamention} = '{diamention_item}'
        ORDER BY {date_col}
        """

query_string = f"""
        SELECT
        *
        FROM `{project_id}.{dataset_id}.{view_name}` 
        WHERE {date_col} BETWEEN '{start_date}' AND '{end_date}' 
        ORDER BY {date_col}
        """

# %%
client = bigquery.Client(credentials=credentials, project=project_id)

# %%
# view_df.Date.values[0]

# %%
# csv_df.Date.values[0]

# %%
view_df.dtypes
# Out:
# Date            datetime64[ns]
# Product_Name            object
# PDP_Views              float64
# Orders                 float64
# add_to_cart            float64
# Revenue                float64
# Quantity               float64
# dtype: object

# %%
print("Start Date:",start_date," End Date:", end_date)

view_df = client.query(query_string_dim).result().to_dataframe()
view_df['Date'] = pd.to_datetime(view_df.Date, format='%Y-%m-%d')
print("View Dataframe Head: \n",view_df.head())
print("View Dataframe Size: (Rows, Columns)",view_df.shape)

csv_df = pd.read_csv('Japan Product Name.csv')
csv_df['Date'] = pd.to_datetime(csv_df.Date, format='%Y-%m-%d')
print("CSV Dataframe Head: \n",csv_df.head())
print("CSV Dataframe Size: (Rows, Columns)",csv_df.shape)
# Out:
# Start Date: 2022-06-20  End Date: 2022-07-20
# View Dataframe Head:
#          Date Product_Name  PDP_Views  Orders  add_to_cart  Revenue  Quantity
# 0 2022-06-20    LR トートバッグ       29.0     0.0          2.0      0.0       0.0
# 1 2022-06-21    LR トートバッグ       13.0     0.0          0.0      0.0       0.0
# 2 2022-06-22    LR トートバッグ       18.0     0.0          0.0      0.0       0.0
# 3 2022-06-23    LR トートバッグ       30.0     0.0          0.0      0.0       0.0
# 4 2022-06-24    LR トートバッグ       44.0     0.0          0.0      0.0       0.0
# View Dataframe Size: (Rows, Columns) (31, 7)
# CSV Dataframe Head:
#          Date                                       Product_Name  Revenue  \
# 0 2021-07-05  1880モデル TRIPLE PLEAT BLOUSE /CONE DENIM/WHITE ...      0.0
# 1 2021-07-05                  1880モデル TRIPLE PLEAT BLOUSE RIGID      0.0
# 2 2021-07-05                         1890モデル XX501® JEANS RIGID      0.0
# 3 2021-07-05                 1890モデル/501XX/WHITE OAK/リジッド/8.8oz      0.0
# 4 2021-07-05                    1936モデル TYPE I トラッカージャケット RIGID      0.0
#
#    Orders  Units  Product_Views  Cart_Adds
# 0       0      0             53          0
# 1       0      0             87          0
# 2       0      0            359          0
# 3       0      0            192          2
# 4       0      0            234          1
# CSV Dataframe Size: (Rows, Columns) (677662, 7)

# %%
daterange = pd.date_range(start_date,end_date-timedelta(days=1),freq='d')
print(daterange)
# Out:
# DatetimeIndex(['2022-06-20', '2022-06-21', '2022-06-22', '2022-06-23',
#                '2022-06-24', '2022-06-25', '2022-06-26', '2022-06-27',
#                '2022-06-28', '2022-06-29', '2022-06-30', '2022-07-01',
#                '2022-07-02', '2022-07-03', '2022-07-04', '2022-07-05',
#                '2022-07-06', '2022-07-07', '2022-07-08', '2022-07-09',
#                '2022-07-10', '2022-07-11', '2022-07-12', '2022-07-13',
#                '2022-07-14', '2022-07-15', '2022-07-16', '2022-07-17',
#                '2022-07-18', '2022-07-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
mask = ((csv_df[date_col] > str(start_date)) & (csv_df[date_col] <= str(end_date)) & (csv_df[primary_diamention] == diamention_item))
masked_df = csv_df.loc[mask]
print(csv_df.shape,masked_df.shape)
# Out:
# (677662, 7) (13, 7)

# %%
masked_df.sort_values(by=date_col,ascending=False)
# Out:
#              Date Product_Name     Revenue  Orders  Units  Product_Views  \
# 677549 2022-07-03    LR トートバッグ   9275.5074       1      2             53
# 675323 2022-07-02    LR トートバッグ   4623.4684       1      1             58
# 672421 2022-07-01    LR トートバッグ      0.0000       0      0             33
# 671748 2022-06-30    LR トートバッグ   5676.8540       1      1             41
# 670073 2022-06-29    LR トートバッグ  17093.9142       3      3             52
# 666488 2022-06-28    LR トートバッグ      0.0000       0      0             24
# 664432 2022-06-27    LR トートバッグ      0.0000       0      0             25
# 662318 2022-06-26    LR トートバッグ      0.0000       0      0             63
# 660253 2022-06-25    LR トートバッグ      0.0000       0      0             31
# 658126 2022-06-24    LR トートバッグ      0.0000       0      0             44
# 656022 2022-06-23    LR トートバッグ      0.0000       0      0             30
# 653973 2022-06-22    LR トートバッグ      0.0000       0      0             18
# 651934 2022-06-21    LR トートバッグ      0.0000       0      0             13
#
#         Cart_Adds
# 677549          2
# 675323          5
# 672421          0
# 671748          4
# 670073         17
# 666488          0
# 664432          0
# 662318          1
# 660253          0
# 658126          0
# 656022          0
# 653973          0
# 651934          0

# %%
view_df.count()
# Out:
# Date            31
# Product_Name    31
# PDP_Views       31
# Orders          31
# add_to_cart     31
# Revenue         31
# Quantity        31
# dtype: int64

# %%
print(query_string_dim)
# Out:
#         SELECT
#         *
#         FROM `watchdog-340107.levis_jp_watchdog.ga_jp_product_daily_kpi`
#         WHERE (Date BETWEEN '2022-06-20' AND '2022-07-20') AND Product_Name = 'LR トートバッグ'
#         ORDER BY Date

# %%
# view_df = client.query(query_string_dim).result().to_dataframe()

# %%
view_df
# Out:
0
# 24       0.0
# 25       0.0
# 26       0.0
# 27       0.0
# 28       1.0
# 29       0.0
# 30       2.0

# %%
view_df[[date_col, 'PDP_Views']]
# Out:
#          Date  PDP_Views
# 0  2022-06-20       29.0
# 1  2022-06-21       13.0
# 2  2022-06-22       18.0
# 3  2022-06-23       30.0
# 4  2022-06-24       44.0
# 5  2022-06-25       31.0
# 6  2022-06-26       63.0
# 7  2022-06-27       25.0
# 8  2022-06-28       24.0
# 9  2022-06-29       52.0
# 10 2022-06-30       41.0
# 11 2022-07-01       33.0
# 12 2022-07-02       58.0
# 13 2022-07-03       53.0
# 14 2022-07-04       33.0
# 15 2022-07-05       47.0
# 16 2022-07-06       17.0
# 17 2022-07-07       51.0
# 18 2022-07-08       81.0
# 19 2022-07-09       68.0
# 20 2022-07-10       76.0
# 21 2022-07-11       55.0
# 22 2022-07-12       50.0
# 23 2022-07-13       48.0
# 24 2022-07-14       37.0
# 25 2022-07-15       38.0
# 26 2022-07-16       40.0
# 27 2022-07-17       78.0
# 28 2022-07-18       58.0
# 29 2022-07-19       71.0
# 30 2022-07-20       61.0

# %%
masked_df[[date_col, 'Product_Views']]
# Out:
#              Date  Product_Views
# 651934 2022-06-21             13
# 653973 2022-06-22             18
# 656022 2022-06-23             30
# 658126 2022-06-24             44
# 660253 2022-06-25             31
# 662318 2022-06-26             63
# 664432 2022-06-27             25
# 666488 2022-06-28             24
# 670073 2022-06-29             52
# 671748 2022-06-30             41
# 672421 2022-07-01             33
# 675323 2022-07-02             58
# 677549 2022-07-03             53

# %%
df = view_df[[date_col, 'PDP_Views']]
d = masked_df[[date_col, 'Product_Views']]

df = df[df[date_col].notnull()]
d = d[d[date_col].notnull()]
# .set_index(date_col)

# df.join(d, on = date_col, how='left')
df.merge(d, on = date_col, how='left').sort_values(by=date_col,ascending=False)
# Out:
#          Date  PDP_Views  Product_Views
# 30 2022-07-20       61.0            NaN
# 29 2022-07-19       71.0            NaN
# 28 2022-07-18       58.0            NaN
# 27 2022-07-17       78.0            NaN
# 26 2022-07-16       40.0            NaN
# 25 2022-07-15       38.0            NaN
# 24 2022-07-14       37.0            NaN
# 23 2022-07-13       48.0            NaN
# 22 2022-07-12       50.0            NaN
# 21 2022-07-11       55.0            NaN
# 20 2022-07-10       76.0            NaN
# 19 2022-07-09       68.0            NaN
# 18 2022-07-08       81.0            NaN
# 17 2022-07-07       51.0            NaN
# 16 2022-07-06       17.0            NaN
# 15 2022-07-05       47.0            NaN
# 14 2022-07-04       33.0            NaN
# 13 2022-07-03       53.0           53.0
# 12 2022-07-02       58.0           58.0
# 11 2022-07-01       33.0           33.0
# 10 2022-06-30       41.0           41.0
# 9  2022-06-29       52.0           52.0
# 8  2022-06-28       24.0           24.0
# 7  2022-06-27       25.0           25.0
# 6  2022-06-26       63.0           63.0
# 5  2022-06-25       31.0           31.0
# 4  2022-06-24       44.0           44.0
# 3  2022-06-23       30.0           30.0
# 2  2022-06-22       18.0           18.0
# 1  2022-06-21       13.0           13.0
# 0  2022-06-20       29.0            NaN

# %%
df.join(d, on = date_col, how='left')

# %%
d.dtypes
# Out:
# Date             datetime64[ns]
# Product_Views             int64
# dtype: object

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# PDP_Views           float64
# dtype: object

# %%
data = df.merge(d,on=date_col,how='left')
